# %%
import rdkit
from rdkit import Chem
from rdkit.Chem import AllChem
from multi_molecule import Multi_Molecule

import ase
import os
from ase import io
from ase.visualize import view
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
results = os.listdir("./results")
master = os.listdir("./master/")
master
# Out:
# ['Ala_master.xyz',
#  'Val_master.xyz',
#  'Ile_master.xyz',
#  'Leu_master.xyz',
#  'Phe_master.xyz',
#  'Trp_master.xyz',
#  'Gly_master.xyz']

# %%
smiles_dict = {
    "Phe" : "NC(CC1=CC=CC=C1)C(=O)O",
    "Gly" : "NCCC(=O)O",
    "Ala" : "NC(C)C(=O)O",
    "Ile" : "NC(C(C)CC)C(=O)O",
    "Leu" : "NC(CC(C)C)C(=O)O",
    "Val" : "NC(C(C)C)C(=O)O",
    "Trp" : "NC(CC1=CNC2=C1(C=CC=C2))C(=O)O"
}

# %%
positions = am.get_positions()
smiles = smiles_dict[name]
mol_m = Multi_Molecule(smiles).rdkit_molecule
conf = mol_m.GetConformers()[0]
for i, atom in enumerate(mol_m.GetAtoms()):
    conf.SetAtomPosition(i, positions[i])
    
positions = ar.get_positions()
smiles = smiles_dict[name]
mol_r = Multi_Molecule(smiles).rdkit_molecule
conf_r = mol_r.GetConformers()[0]
for i, atom in enumerate(mol_r.GetAtoms()):
    conf_r.SetAtomPosition(i, positions[i])
    
conf_r.SetId(1)
mol_m.AddConformer(conf_r)
    
AllChem.GetConformerRMS(mol_m, 0, 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-060940d7ed9b> in <module>()
# ----> 1 positions = am.get_positions()
#       2 smiles = smiles_dict[name]
#       3 mol_m = Multi_Molecule(smiles).rdkit_molecule
#       4 conf = mol_m.GetConformers()[0]
#       5 for i, atom in enumerate(mol_m.GetAtoms()):
#
# NameError: name 'am' is not defined

# %%
from ase.calculators.emt import EMT
from ase.calculators.ff import ForceField
from ase.calculators.lj import LennardJones
potential_results = []
for m in master:
    for r in results:
        if m.split("_")[0] == r.split("_")[0]:
            try:
                name = m.split("_")[0]
                print name
                #mol = Multi_Molecule(smiles)

                am = io.read("./master/" + m)
                ar = io.read("./results/" + r)
                am.set_calculator(LennardJones())
                ar.set_calculator(LennardJones())
                
                print am.get_potential_energy() - ar.get_potential_energy()
                
                
                
                
                positions = am.get_positions()
                smiles = smiles_dict[name]
                mol_m = Multi_Molecule(smiles).rdkit_molecule
                conf = mol_m.GetConformers()[0]
                for i, atom in enumerate(mol_m.GetAtoms()):
                    conf.SetAtomPosition(i, positions[i])
                    
                

                positions = ar.get_positions()
                smiles = smiles_dict[name]
                mol_r = Multi_Molecule(smiles).rdkit_molecule
                conf_r = mol_r.GetConformers()[0]
                for i, atom in enumerate(mol_r.GetAtoms()):
                    conf_r.SetAtomPosition(i, positions[i])

                conf_r.SetId(1)
                mol_m.AddConformer(conf_r)

                print AllChem.GetConformerRMS(mol_m, 0, 1)
                print
                #mol.ase_molecule = a
                #print len(mol.rmg_molecule.atoms)
                #print len(a.get_atomic_numbers())
                #mol.update_geometry_from_ase_mol()
                #print abs(ar.get_all_distances() - am.get_all_distances()).max()
                potential_results.append([name, am.get_potential_energy() - ar.get_potential_energy()])
            except IndexError:
                print "there was an error... hmmm"
                print
# Out:
# Ala
# -1.47788269074
# 2.38789067432
#
# Ala
# -1.467246246
# 2.39450761823
#
# Ala
# -1.45494788016
# 2.40125293109
#
# Ala
# -1.47363982419
# 2.39391374663
#
# Ala
# -1.42676230249
# 2.43122586653
#
# Ala
# -1.47061997173
# 2.38660155163
#
# Ala
# -1.45302530905
# 2.3928579701
#
# Ala
# -1.47301303014
# 2.38690394054
#
# Ala
# -1.47374514729
# 2.39308537572
#
# Ala
# -1.47037872817
# 2.39375977734
#
# Ala
# -1.46700366489
# 2.39019540744
#
# Ala
# -1.46797737143
# 2.39450133701
#
# Ala
# -1.436277845
# 2.39464601441
#
# Ala
# -1.4671737415
# 2.39431640735
#
# Ala
# -1.47301644575
# 2.39356557047
#
# Ala
# -1.48094622888
# 2.39313223408
#
# Ala
# -1.4719825464
# 2.39358157132
#
# Ala
# -1.43985024898
# 2.39435366428
#
# Ala
# -1.47797774772
# 2.38786943861
#
# Ala
# -1.47587629689
# 2.39205193503
#
# Ala
# -1.46894394251
# 2.39431522112
#
# Ala
# -1.46515842756
# 2.39236996676
#
# Ala
# -1.47862569756
# 2.39747920358
#
# Ala
# -1.46978505354
# 2.3907677509
#
# Ala
# -1.44863477573
# 2.39271295158
#
# Ala
# -1.45979022445
# 2.42694992774
#
# Ala
# -1.46122257412
# 2.39319123303
#
# Ala
# -1.44734733521
# 2.39186474264
#
# Ala
# -1.43358496049
# 2.38998826635
#
# Ala
# -1.46277489164
# 2.39452563693
#
# Ala
# -1.47054243571
# 2.3925892142
#
# Ala
# -1.46363306726
# 2.39457267815
#
# Ala
# -1.46991091836
# 2.39230601037
#
# Ala
# -1.48331860513
# 2.39141090477
#
# Ala
# -1.46710203565
# 2.38908791868
#
# Ala
# -1.46605277562
# 2.39412013112
#
# Ala
# -1.47585952271
# 2.38726423914
#
# Ala
# -1.4723909402
# 2.39377074629
#
# Ala
# -1.4797282975
# 2.39103650252
#
# Ala
# -1.44957549746
# 2.39273254035
#
# Ala
# -1.45492691541
# 2.40027852478
#
# Ala
# -1.46277121012
# 2.3949331269
#
# Val
# -1.53367204105
# 2.737536857
#
# Val
# -1.5253473628
# 2.68456583067
#
# Val
# -1.53143830013
# 2.71312445824
#
# Val
# -1.40167794347
# 2.57977239257
#
# Val
# -1.51049546717
# 2.69967172099
#
# Val
# -1.47123364625
# 2.63464462342
#
# Val
# -1.49161445666
# 2.67670770895
#
# Val
# -1.47225035183
# 2.78550364067
#
# Val
# -1.50012083976
# 2.71928459011
#
# Val
# -1.4583207937
# 2.7330659119
#
# Val
# -1.47548434864
# 2.70918881715
#
# Val
# -1.54290448312
# 2.70423181067
#
# Val
# -1.51421879724
# 2.72566778652
#
# Val
# -1.50740284396
# 2.78421024741
#
# Phe
# -1.56577058484
# 3.36172773942
#
# Phe
# -1.56568992111
# 3.29255464465
#
# Phe
# -1.55819349729
# 3.26281216471
#
# Phe
# -1.52541569227
# 3.33863680963
#
# Phe
# -1.52154732154
# 3.43074324251
#
# Phe
# -1.5243003588
# 3.38679603648
#
# Phe
# -1.52657498415
# 3.40950525987
#
# Trp
# -1.61485776455
# 3.92489890135
#
# Trp
# -1.80328412373
# 4.04062022402
#
# Trp
# -1.70219805131
# 4.00455647353
#
# Trp
# -1.66545632128
# 4.05504813771
#
# Trp
# -1.63679089659
# 3.92378802012
#
# Trp
# -1.59360059354
# 3.91601144886
#
# Trp
# -1.73857263273
# 4.05547573625
#
# Trp
# -1.67976721456
# 4.0572348477
#
# Gly
# 1.00212898109
# there was an error... hmmm
#
# Gly
# 1.4005643257
# there was an error... hmmm
#
# Gly
# 0.940491886755
# there was an error... hmmm
#
# Gly
# 1.00031244789
# there was an error... hmmm
#
# Gly
# 1.42180892445
# there was an error... hmmm
#
# Gly
# 0.937723260888
# there was an error... hmmm
#
# Gly
# 1.03489191593
# there was an error... hmmm
#
# Gly
# 1.00765370681
# there was an error... hmmm
#
# Gly
# 1.00230483134
# there was an error... hmmm
#
# Gly
# 1.02978252794
# there was an error... hmmm
#
# Gly
# 1.01718155481
# there was an error... hmmm
#
# Gly
# 1.02455048891
# there was an error... hmmm
#
# Gly
# 2.02610960571
# there was an error... hmmm
#
# Gly
# 1.00393683533
# there was an error... hmmm
#
# Gly
# 1.01631356658
# there was an error... hmmm
#
# Gly
# 0.896440139694
# there was an error... hmmm
#
# Gly
# 1.39098479444
# there was an error... hmmm
#
# Gly
# 2.03178850014
# there was an error... hmmm
#
# Gly
# 1.0582034549
# there was an error... hmmm
#
# Gly
# 1.00365425312
# there was an error... hmmm
#
# Gly
# 1.01834367684
# there was an error... hmmm
#
# Gly
# 1.43859702546
# there was an error... hmmm
#
# Gly
# 1.43215641338
# there was an error... hmmm
#
# Gly
# 1.06282842295
# there was an error... hmmm
#
# Gly
# 1.06181926046
# there was an error... hmmm
#
# Gly
# 0.98361792475
# there was an error... hmmm
#
# Gly
# 1.05794910339
# there was an error... hmmm
#
# Gly
# 1.02807193927
# there was an error... hmmm
#
# Gly
# 1.0717121911
# there was an error... hmmm
#
# Gly
# 2.04350809281
# there was an error... hmmm
#
# Gly
# 1.0144483202
# there was an error... hmmm
#
# Gly
# 1.59086772321
# there was an error... hmmm
#
# Gly
# 1.01678285366
# there was an error... hmmm
#
# Gly
# 2.0102542144
# there was an error... hmmm
#
# Gly
# 1.36886510526
# there was an error... hmmm
#
# Gly
# 1.38305461241
# there was an error... hmmm
#
# Gly
# 0.953412254641
# there was an error... hmmm
#
# Gly
# 1.03364130336
# there was an error... hmmm
#
# Gly
# 1.94144011156
# there was an error... hmmm
#
# Gly
# 1.03445609054
# there was an error... hmmm

# %%
potential_results = pd.DataFrame(potential_results)
potential_results.columns = ["AA" , "delta_e"]
potential_results.set_index("AA")
# Out:
#       delta_e
# AA
# Ala -1.477883
# Ala -1.467246
# Ala -1.454948
# Ala -1.473640
# Ala -1.426762
# Ala -1.470620
# Ala -1.453025
# Ala -1.473013
# Ala -1.473745
# Ala -1.470379
# Ala -1.467004
# Ala -1.467977
# Ala -1.436278
# Ala -1.467174
# Ala -1.473016
# Ala -1.480946
# Ala -1.471983
# Ala -1.439850
# Ala -1.477978
# Ala -1.475876
# Ala -1.468944
# Ala -1.465158
# Ala -1.478626
# Ala -1.469785
# Ala -1.448635
# Ala -1.459790
# Ala -1.461223
# Ala -1.447347
# Ala -1.433585
# Ala -1.462775
# ..        ...
# Phe -1.493505
# Phe -1.558932
# Phe -1.508415
# Phe -1.516312
# Phe -1.483899
# Phe -1.548535
# Phe -1.498162
# Phe -1.468689
# Phe -1.537702
# Phe -1.511376
# Phe -1.540694
# Phe -1.536642
# Phe -1.550627
# Phe -1.531113
# Phe -1.523590
# Phe -1.565771
# Phe -1.565690
# Phe -1.558193
# Phe -1.525416
# Phe -1.521547
# Phe -1.524300
# Phe -1.526575
# Trp -1.614858
# Trp -1.803284
# Trp -1.702198
# Trp -1.665456
# Trp -1.636791
# Trp -1.593601
# Trp -1.738573
# Trp -1.679767
#
# [189 rows x 1 columns]

# %%
for name in smiles_dict.iterkeys():
    print name
    print potential_results[potential_results.AA == name].delta_e.mean()
    print potential_results[potential_results.AA == name].delta_e.shape
    potential_results[potential_results.AA == name].hist(bins = 10)
# Out:
# Ile
# -1.5083426341
# (31,)
# Val
# -1.50143638786
# (41,)
# Phe
# -1.52981847794
# (32,)
# Ala
# -1.46454817551
# (42,)
# Gly
# nan
# (0,)
# Leu
# -1.52548733105
# (35,)
# Trp
# -1.67931594979
# (8,)

# %%
mol.rmg_molecule.atoms
# Out:
# [<Atom 'C'>,
#  <Atom 'C'>,
#  <Atom 'C'>,
#  <Atom 'C'>,
#  <Atom 'C'>,
#  <Atom 'C'>,
#  <Atom 'N'>,
#  <Atom 'C'>,
#  <Atom 'C'>,
#  <Atom 'C'>,
#  <Atom 'C'>,
#  <Atom 'C'>,
#  <Atom 'N'>,
#  <Atom 'O'>,
#  <Atom 'H'>,
#  <Atom 'H'>,
#  <Atom 'H'>,
#  <Atom 'O'>,
#  <Atom 'H'>,
#  <Atom 'H'>,
#  <Atom 'H'>,
#  <Atom 'H'>,
#  <Atom 'H'>,
#  <Atom 'H'>,
#  <Atom 'H'>,
#  <Atom 'H'>,
#  <Atom 'H'>]

# %%
abs(ar.get_all_distances() - am.get_all_distances()).mean()
# Out:
# 2.0130040770707396

# %%
r, m.split("_")[0]
# Out:
# ('Ala_235.xyz', 'Phe')

# %%
import sys
a = True
b = False
if a:
    if not b:
        print b
        sys.exit()
        
    b = True
    print b
# Out:
# False
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# To exit: use 'exit', 'quit', or Ctrl-D.
