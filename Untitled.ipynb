# %%
from autotst.molecule import *
from autotst.conformer.simple_es import *
from autotst.conformer.ga import *
from autotst.conformer.brute_force import *
from autotst.conformer.utilities import *
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-6783225ca2fb> in <module>()
#       1 from autotst.molecule import *
# ----> 2 from autotst.conformer.simple_es import *
#       3 from autotst.conformer.ga import *
#       4 from autotst.conformer.brute_force import *
#       5 from autotst.conformer.utilities import *
#
# /Users/nathan/Code/AutoTST/autotst/conformer/simple_es.py in <module>()
#      24
#      25 from rmgpy.molecule import Molecule
# ---> 26 from rmgpy.species import Species
#      27 from rmgpy.reaction import Reaction
#      28
#
# /Users/nathan/Code/RMG-Py/rmgpy/quantity.pxd in init rmgpy.species()
#      32 ################################################################################
#      33
# ---> 34 cdef class Units(object):
#      35
#      36     cdef public str units
#
# /Users/nathan/Code/RMG-Py/rmgpy/quantity.py in init rmgpy.quantity()
#      35
#      36 import numpy
# ---> 37 import quantities as pq
#      38
#      39 import rmgpy.constants as constants
#
# /Users/nathan/anaconda/envs/tst_env/lib/python2.7/site-packages/quantities/__init__.py in <module>()
#     283 from .unitquantity import *
#     284
# --> 285 from .units import *
#     286
#     287 from . import constants
#
# /Users/nathan/anaconda/envs/tst_env/lib/python2.7/site-packages/quantities/units/__init__.py in <module>()
#       7 from .prefixes import *
#       8
# ----> 9 from . import acceleration
#      10 from .acceleration import *
#      11
#
# /Users/nathan/anaconda/envs/tst_env/lib/python2.7/site-packages/quantities/units/acceleration.py in <module>()
#       5
#       6 from ..unitquantity import UnitQuantity
# ----> 7 from .time import s
#       8 from .length import m
#       9
#
# /Users/nathan/anaconda/envs/tst_env/lib/python2.7/site-packages/quantities/units/time.py in <module>()
#      16     s/1000,
#      17     'ms',
# ---> 18     aliases=['milliseconds']
#      19 )
#      20 us = microsecond = UnitTime(
#
# /Users/nathan/anaconda/envs/tst_env/lib/python2.7/site-packages/quantities/unitquantity.pyc in __new__(cls, name, definition, symbol, u_symbol, aliases, doc)
#      60                 definition *= dimensionless
#      61             ret._definition = definition
# ---> 62             ret._conv_ref = definition._reference
#      63         else:
#      64             ret._definition = None
#
# /Users/nathan/anaconda/envs/tst_env/lib/python2.7/site-packages/quantities/quantity.pyc in _reference(self)
#     137         rq = 1*unit_registry['dimensionless']
#     138         for u, d in self.dimensionality.items():
# --> 139             rq = rq * u._reference**d
#     140         return rq * self.magnitude
#     141
#
# /Users/nathan/anaconda/envs/tst_env/lib/python2.7/site-packages/quantities/unitquantity.pyc in __pow__(self, other)
#     228     @with_doc(Quantity.__pow__, use_header=False)
#     229     def __pow__(self, other):
# --> 230         return self.view(Quantity).__pow__(other)
#     231
#     232     @with_doc(Quantity.__rpow__, use_header=False)
#
# /Users/nathan/anaconda/envs/tst_env/lib/python2.7/site-packages/quantities/quantity.pyc in g(self, other, *args)
#      86         except AssertionError:
#      87             raise ValueError('Quantities must be raised to a uniform power')
# ---> 88         return f(self, other, *args)
#      89     return g
#      90
#
# /Users/nathan/anaconda/envs/tst_env/lib/python2.7/site-packages/quantities/quantity.pyc in __pow__(self, other)
#     319     @check_uniform
#     320     def __pow__(self, other):
# --> 321         return super(Quantity, self).__pow__(other)
#     322
#     323     @with_doc(np.ndarray.__ipow__)
#
# /Users/nathan/anaconda/envs/tst_env/lib/python2.7/site-packages/quantities/quantity.pyc in __array_prepare__(self, obj, context)
#     234                 """ufunc %r not supported by quantities
#     235                 please file a bug report at https://github.com/python-quantities
# --> 236                 """ % uf
#     237                 )
#     238         return res
#
# ValueError: ufunc <ufunc 'positive'> not supported by quantities
#                 please file a bug report at https://github.com/python-quantities
